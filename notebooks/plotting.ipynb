# %%
import sys
sys.path.insert(0, '../')

# %%
import matplotlib
# %matplotlib inline

# %%
from dpn.utils import plt
from dpn.exps.synthetic_data import exp
from collections import namedtuple

# %%
Args = namedtuple('Args', 'output_dir radius sigma num_points prefix')
args = Args(output_dir='../outputs/synthetic', radius=8.0, sigma=1.0, num_points=200, prefix='kldiv')
exp(args)
